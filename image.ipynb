# %% [markdown]
# <a href="https://colab.research.google.com/github/JurijJusel/Image/blob/t3-dir-reader/image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
img1 = cv2.imread('/content/Image_10.jpg')
# img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB
plt.imshow(img1)
# img.shape
# type(img)

# %%
cv2.circle(img1, (600,600), 400,(0,255,0),5)
img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
plt.imshow(img1)

# %%
img2 = cv2.imread('/content/Image_6.jpg')
# img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB
plt.imshow(img2)
# img.shape
# type(img)

# %%
cv2.rectangle(img2,(250,120),(1100,670),(0,0,250),5)
img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)
plt.imshow(img2)

# %% [markdown]
# # New Section

# %%
img3 = cv2.imread('/content/Image_4.jpg')
# cv2.rectangle(img3,(250,120),(1100,670),(0,0,250),5)
# img2 = cv2.cvtColor(img3, cv2.COLOR_BGR2RGB)
plt.imshow(img3)

# %%
p1 = (670, 20)
p2 = (180, 1080)
p3 = (1150, 1080)

cv2.line(img3, p1, p2, (0, 0, 255), 5)
cv2.line(img3, p2, p3, (0, 0, 255), 5)
cv2.line(img3, p1, p3, (0, 0, 255), 5)
  
img3 = cv2.cvtColor(img3, cv2.COLOR_BGR2RGB)  
plt.imshow(img3)

# %%
# def resize_image(img):
    # img = cv2.imread(image_path)
img_resized = cv2.resize(img3, (122, 122))
img_array = np.array(img_resized)
plt.imshow(img_array)
# img_array

# %%
img_array
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...
